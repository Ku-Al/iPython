# %%
import numpy as np
import pandas as pd
import math
# %pylab inline

LENGTH_FILE = "D:/dd"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.load('D:/dd/trips.npy')
print np.size(data[0])/2
# Out:
# 863

# %%
for dr in data:
    i = 0
    v = []
    while i < (np.size(dr)/2-1):
        v.append(math.hypot((dr[i+1][0] - dr[i][0]),(dr[i+1][1] - dr[i][1])))
        i += 1
    pd.set_option('display.mpl_style', 'default') 
    pd.set_option('display.line_width', 5000) 
    fig = plt.figure(figsize(10, 10), dpi=100)
    fig, axes = plt.subplots(figsize=(20,10))
    axes.hist(v)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 133
