# %%
import pandas as pd
import matplotlib.pyplot as plt  
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

# %%
cd D:\pythone\iPython\Takeout\history
# Out:
# D:\pythone\iPython\Takeout\history

# %%
raw = pd.io.json.read_json('history.json')

# %%
raw.tail()
# Out:
#                                                 locations
# 300666  {u'latitudeE7': 480498834, u'accuracy': 20, u'...
# 300667  {u'activitys': [{u'activities': [{u'confidence...
# 300668  {u'latitudeE7': 480498829, u'accuracy': 20, u'...
# 300669  {u'activitys': [{u'activities': [{u'confidence...
# 300670  {u'activitys': [{u'activities': [{u'confidence...
#
# [5 rows x 1 columns]

# %%
df = raw['locations'].apply(pd.Series)

# %%
df.tail()
# Out:
#         accuracy                                          activitys  altitude  \
# 300666        20                                                NaN       NaN
# 300667        20  [{u'activities': [{u'confidence': 92, u'type':...       NaN
# 300668        20                                                NaN       NaN
# 300669        20  [{u'activities': [{u'confidence': 61, u'type':...       NaN
# 300670        10  [{u'activities': [{u'confidence': 42, u'type':...       NaN
#
#         heading  latitudeE7  longitudeE7    timestampMs  velocity
# 300666      NaN   480498834    380186063  1399380422747       NaN
# 300667      NaN   480498828    380186042  1399380362653       NaN
# 300668      NaN   480498829    380186112  1399380301745       NaN
# 300669      NaN   480498811    380186076  1399380228659       NaN
# 300670      NaN   480498831    380186104  1399380130333       NaN
#
# [5 rows x 8 columns]

# %%
df['latitude'] = df['latitudeE7'] * 0.0000001
df['longitude'] = df['longitudeE7'] * 0.0000001

# %%
# Create a figure of size (i.e. pretty big)
fig = plt.figure(figsize=(20,10))

# Create a map, using the Gall–Peters projection, 
map = Basemap(projection='gall',  
              # with low resolution,
              resolution = 'l', 
              # And threshold 100000
              area_thresh = 100000.0,
              # Centered at 0,0 (i.e null island)
              lat_0=0, lon_0=30,
              llcrnrlon=10.,llcrnrlat=36.,urcrnrlon=50.,urcrnrlat=58.
              )

# Draw the coastlines on the map
map.drawcoastlines()

# Draw country borders on the map
map.drawcountries()

# Fill the land with grey
map.fillcontinents(color = '#408860')

# Draw the map boundaries
map.drawmapboundary(fill_color='#f4f4f4')

# Define our longitude and latitude points
x,y = map(df['longitude'].values, df['latitude'].values)

# Plot them using round markers of size 6
map.plot(x, y, 'ro', markersize=3)

# Show the map
plt.show()
