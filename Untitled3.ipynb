# %%
import urllib2
import sys
#import csv
#import bleach
import codecs
import time
import re

def tr(x): 
    if x: return x.get_text()
    else: return u"-"

# %%
from bs4 import BeautifulSoup

page = urllib2.urlopen('https://www.yandex.ua/?ncrnd=143&amp;nocookiesupport=yes')
soup = BeautifulSoup(page)

#UTF8Writer = codecs.getwriter('utf8')
#sys.stdout = UTF8Writer(sys.stdout) #Out UTF-8 text

t = time.strftime("%Y-%m-%d %H:%M") #Curent time

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="i-ua_js_no i-ua_css_standart i-ua_browser_ i-ua_pseudo_yes" lang="uk">
#  <head xmlns:og="http://ogp.me/ns#">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Яндекс
#   </title>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <link href="//yastatic.net/morda-logo/i/apple-touch-icon/ru-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//yastatic.net/morda-logo/i/apple-touch-icon/ru-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//yastatic.net/morda-logo/i/apple-touch-icon/ru-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//yastatic.net/morda-logo/i/apple-touch-icon/ru-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="//company.yandex.ru/news/news.rss" rel="alternate" title="Новини Яндекса" type="application/rss+xml"/>
# ...

# %%
x = soup.body.find('span', attrs={'class' : 'b-traffic__rate'}) #Curent balls text
xx = x.find('a', attrs={'class' : 'b-link_black_novisit'})
y = soup.body.find('div', attrs={'class' : 'b-traffic__informer b-traffic__informer_nojams'}) #If no forecast
yy = soup.body.find('a', attrs={'class' : 'b-link b-traffic__descr'})#Curent forecast descriptions
z = soup.body.find('div', attrs={'class' : 'b-traffic__forecast'})

print tr(xx), tr(y), tr(yy)

for e in z:
    print e
    print e.find_next('div', attrs={'class' : 'b-traffic-forecast__value'}).text
    print e.find_next('span', attrs={'class' : 'b-traffic-forecast__time'}).text
    
    
                 
#    print z.next_elements('div', attrs={'class' : 'b-traffic-forecast__value-3'}).text
#   print z.find('span', attrs={'class' : 'b-traffic-forecast__time'}).text
# Out:
# 2 бали - Дороги майже вільні
# <span class="b-traffic-forecast__title">Прогноз</span>
# 2
# 15 г
# <span class="b-traffic-forecast"><div class="b-traffic-forecast__value b-traffic-forecast__value-2">2</div><span class="b-traffic-forecast__time">15 г </span></span>
# 2
# 15 г
# <span class="b-traffic-forecast"><div class="b-traffic-forecast__value b-traffic-forecast__value-2">2</div><span class="b-traffic-forecast__time">16</span></span>
# 2
# 16
# <span class="b-traffic-forecast"><div class="b-traffic-forecast__value b-traffic-forecast__value-2">2</div><span class="b-traffic-forecast__time">17</span></span>
# 2
# 17
# <span class="b-traffic-forecast"><div class="b-traffic-forecast__value b-traffic-forecast__value-3">3</div><span class="b-traffic-forecast__time">18</span></span>
# 3
# 18
# <span class="b-traffic-forecast"><div class="b-traffic-forecast__value b-traffic-forecast__value-4">4</div><span class="b-traffic-forecast__time">19</span></span>
# 4
# 19
