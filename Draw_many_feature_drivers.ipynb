# %%
cd D:\\dd\\telematic\\telematics
# Out:
# D:\dd\telematic\telematics

# %%
import numpy as np
import os
import math
import pandas as pd
from sklearn import preprocessing
# %pylab inline


from plotly.widgets import GraphWidget
from plotly.graph_objs import *
import plotly.plotly as py
import plotly.tools as tls
from sklearn import preprocessing
from IPython.html import widgets 
from IPython.display import display, clear_output

DRIVERS_DATA_DIR = "data\\drivers"

 
feature = {'Legth':0, 'Velocity':1, 'Acceleration':2}
type_graph = {'Graph':0, 'Hist':1}
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def draw_widgets():
    #quantity_graph = widgets.IntSliderWidget()
    quantity_graph.min= 10
    quantity_graph.max= 200
    quantity_graph.value = 10
    quantity_graph.description = 'Number of graphs'
    
    #choise_feature_dropdown = widgets.DropdownWidget()
    choise_feature_dropdown.values  = feature
    choise_feature_dropdown.value = 0
    choise_feature_dropdown.description = 'Select feature for research'
    
    #choise_graph_dropdown = widgets.DropdownWidget()
    choise_graph_dropdown.values  = type_graph
    choise_graph_dropdown.value = 0
    choise_graph_dropdown.description = 'Select which type of graph'
    
    #driver_number_text_input = widgets.TextWidget()
    driver_number_text_input.description = 'The driver number'
    driver_number_text_input.value = '1' 
    
    display(quantity_graph)
    display(choise_feature_dropdown)
    display(choise_graph_dropdown)
    display(driver_number_text_input)
    

def on_trait_change():
    print "Change", driver_number_text_input.value
    choise_driver(driver_number_text_input.value, choise_feature_dropdown.value)

def draw_graph_len(data, cur_pos):
    pos = cur_pos - 10
    while pos < cur_pos:
        pd.set_option('display.mpl_style', 'default') 
        pd.set_option('display.line_width', 4500) 
        fig = plt.figure(figsize(10, 10), dpi=100)
        fig, axes = plt.subplots(figsize=(20,10))
        axes.set_xlabel('x')
        axes.set_ylabel('y')
        ax = 'Length {}'.format(pos)
        axes.set_title(ax)
        axes.plot(data[pos][:, 0], data[pos][:, 1], 'g')
        pos += 1    
    
def draw_graph(data, cur_pos):
    pos = cur_pos - 10
    while pos < cur_pos:
        v, v_mean, v_median, v_std = calculate_driver_velocitys(data[pos])
        draw_mean(v, 0, pos)
        pos += 1
         
def draw_mean(v_cur, type, pos):
    pd.set_option('display.mpl_style', 'default') 
    pd.set_option('display.line_width', 4500) 
    fig = plt.figure(figsize(10, 10), dpi=100)
    fig, axes = plt.subplots(figsize=(20,10))
    axes.plot(v_cur, 'g')
    axes.set_xlabel('Time')
    if type == 0:
        ax_l = 'Vel'
        ax_t = 'Velocity {}'.format(pos)
    else: 
        ax_l = 'Acc'
        ax_t = 'Acceleration {}'.format(pos)
    axes.set_ylabel(ax_l)
    axes.set_title(ax_t);
    
def draw_graph_accel(data, cur_pos):
    pos = cur_pos - 10
    while pos < cur_pos:
        v, v_mean, v_median, v_std = calculate_driver_velocitys(data[pos])
        a, a_mean, a_median, a_std = calculate_driver_acceleration(v)
        draw_mean(mean_accel_driver, a, 1, pos)
        pos += 1

# %%
def calculate_driver_acceleration(v):
    a = np.diff(v)
    return a, np.mean(a), np.median(a), np.std(a)


def calculate_driver_velocitys(data):
    #data_n = preprocessing.normalize(data)
    v = np.hypot(np.diff(data[:, 0]), np.diff(data[:, 1]))
    #v_n = preprocessing.normalize(v)
    return v, np.mean(v), np.median(v), np.std(v)

def choise_driver(driver, feature):
    mean_velos_driver = []
    mean_acceler_driver = []
    path = os.path.join(DRIVERS_DATA_DIR, driver, '{}.npy'.format(driver))
    if os.path.exists(path):
        data = np.load(path)
        if feature==0:
            print "Lenght"
            draw_graph_len(data, quantity_graph.value)
        if feature==1:
            print "Velocity"
            draw_graph(data, quantity_graph.value)
        if feature==2:
            print "acceleration"
            draw_graph_accel(data, quantity_graph.value)
            
            
    else: 
        print('File {} not found'.format(path))

# %%
quantity_graph = widgets.IntSliderWidget()
choise_feature_dropdown = widgets.DropdownWidget()
choise_graph_dropdown = widgets.DropdownWidget()
driver_number_text_input = widgets.TextWidget()

draw_widgets()

quantity_graph.on_trait_change(on_trait_change, 'value')
choise_feature_dropdown.on_trait_change(on_trait_change, 'value')
choise_graph_dropdown.on_trait_change(on_trait_change, 'value')
driver_number_text_input.on_trait_change(on_trait_change, 'value')
# Out:
# Change 1
# Velocity
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# line_width has been deprecated, use display.width instead (currently both are
# identical)
#
#
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# line_width has been deprecated, use display.width instead (currently both are
# identical)
#
#
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# line_width has been deprecated, use display.width instead (currently both are
# identical)
#
#
# C:\Anaconda\lib\site-packages\pandas\core\config.py:570: DeprecationWarning:
#
# ...
